# %% [markdown]
# <a href="https://colab.research.google.com/github/VilmaTar/pre-corse/blob/pre-course/11Loading_a_dataset_from_remote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nauja skiltis

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/First commit of demo notebook/nbaallelo.csv')
df1
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 0               1  194611010TRH   NBA  ...            L  0.640065   NaN
# 1               1  194611010TRH   NBA  ...            W  0.359935   NaN
# 2               2  194611020CHS   NBA  ...            W  0.631101   NaN
# 3               2  194611020CHS   NBA  ...            L  0.368899   NaN
# 4               3  194611020DTF   NBA  ...            L  0.640065   NaN
# ...           ...           ...   ...  ...          ...       ...   ...
# 126309      63155  201506110CLE   NBA  ...            L  0.546572   NaN
# 126310      63156  201506140GSW   NBA  ...            W  0.765565   NaN
# 126311      63156  201506140GSW   NBA  ...            L  0.234435   NaN
# 126312      63157  201506170CLE   NBA  ...            L  0.481450   NaN
# 126313      63157  201506170CLE   NBA  ...            W  0.518550   NaN
#
# [126314 rows x 23 columns]

# %%
# !wget - 0 nbaaellelo.csv https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv
# Out:
# --2021-08-04 08:23:37--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# --2021-08-04 08:23:37--  http://0/
# Resolving 0 (0)... 0.0.0.0
# Connecting to 0 (0)|0.0.0.0|:80... failed: Connection refused.
# --2021-08-04 08:23:37--  http://nbaaellelo.csv/
# Resolving nbaaellelo.csv (nbaaellelo.csv)... failed: Name or service not known.
# wget: unable to resolve host address ‘nbaaellelo.csv’
# --2021-08-04 08:23:37--  https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18173265 (17M) [text/plain]
# Saving to: ‘nbaallelo.csv.1’
#
# nbaallelo.csv.1     100%[===================>]  17.33M  48.6MB/s    in 0.4s
#
# ...

# %%
import pandas as pd

# %%
df2 = pd.read_csv("/content/nbaallelo.csv.1")

df2
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 0               1  194611010TRH   NBA  ...            L  0.640065   NaN
# 1               1  194611010TRH   NBA  ...            W  0.359935   NaN
# 2               2  194611020CHS   NBA  ...            W  0.631101   NaN
# 3               2  194611020CHS   NBA  ...            L  0.368899   NaN
# 4               3  194611020DTF   NBA  ...            L  0.640065   NaN
# ...           ...           ...   ...  ...          ...       ...   ...
# 126309      63155  201506110CLE   NBA  ...            L  0.546572   NaN
# 126310      63156  201506140GSW   NBA  ...            W  0.765565   NaN
# 126311      63156  201506140GSW   NBA  ...            L  0.234435   NaN
# 126312      63157  201506170CLE   NBA  ...            L  0.481450   NaN
# 126313      63157  201506170CLE   NBA  ...            W  0.518550   NaN
#
# [126314 rows x 23 columns]

# %% [markdown]
# assert df1.equals(df2)

# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/First commit of demo notebook/nbaallelo.csv')
df2 = pd.read_csv('/content/nbaallelo.csv.1')

result1 = df1[~df1.apply(tuple, 1).isin(df2.apply(tuple,1))]
print(rezult1)

# %%
import pandas as pdv
df1 = pd.read_csv('/content/nbaallelo.csv.1')
df2 = pd.read_csv('/content/nbaallelo.csv.1')
assert df1.equals(df2)
df1.head(5)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-50-291a0b560ac8> in <module>()
#       1 import pandas as pd
#       2 df1 = pd.read_csv('/content/drive/MyDrive/First commit of demo notebook/nbaallelo.csv')
# ----> 3 df2 = pd.read_csv('/content/nbaallelo.csv.1/nbaallelo.csv.1')
#       4 assert df1.equals(df2)
#       5 df1.head(5)
#
# ...

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/First commit of demo notebook/nbaallelo.csv')
df2 = pd.read_csv('/content/nbaallelo.csv.1')
assert df1.equals(df2)

# %%
df1
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 0               1  194611010TRH   NBA  ...            L  0.640065   NaN
# 1               1  194611010TRH   NBA  ...            W  0.359935   NaN
# 2               2  194611020CHS   NBA  ...            W  0.631101   NaN
# 3               2  194611020CHS   NBA  ...            L  0.368899   NaN
# 4               3  194611020DTF   NBA  ...            L  0.640065   NaN
# ...           ...           ...   ...  ...          ...       ...   ...
# 126309      63155  201506110CLE   NBA  ...            L  0.546572   NaN
# 126310      63156  201506140GSW   NBA  ...            W  0.765565   NaN
# 126311      63156  201506140GSW   NBA  ...            L  0.234435   NaN
# 126312      63157  201506170CLE   NBA  ...            L  0.481450   NaN
# 126313      63157  201506170CLE   NBA  ...            W  0.518550   NaN
#
# [126314 rows x 23 columns]

# %%
df1.head(5)
# Out:
#    gameorder       game_id lg_id  ...  game_result  forecast notes
# 0          1  194611010TRH   NBA  ...            L  0.640065   NaN
# 1          1  194611010TRH   NBA  ...            W  0.359935   NaN
# 2          2  194611020CHS   NBA  ...            W  0.631101   NaN
# 3          2  194611020CHS   NBA  ...            L  0.368899   NaN
# 4          3  194611020DTF   NBA  ...            L  0.640065   NaN
#
# [5 rows x 23 columns]
