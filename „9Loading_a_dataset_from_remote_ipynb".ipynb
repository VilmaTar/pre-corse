# %% [markdown]
# <a href="https://colab.research.google.com/github/VilmaTar/pre-corse/blob/pre-course/%E2%80%9E9Loading_a_dataset_from_remote_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nauja skiltis

# %%
! ls

# %cd nbaallelo_csv

! ls

! pwd
# Out:
# nbaallelo.csv  nbaallelo.csv.1	nbaallelo.csv.2  sample_data
# [Errno 2] No such file or directory: 'nbaallelo_csv'
# /content
# nbaallelo.csv  nbaallelo.csv.1	nbaallelo.csv.2  sample_data
# /content

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/First commit of demo notebook/nbaallelo.csv')
df1
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 0               1  194611010TRH   NBA  ...            L  0.640065   NaN
# 1               1  194611010TRH   NBA  ...            W  0.359935   NaN
# 2               2  194611020CHS   NBA  ...            W  0.631101   NaN
# 3               2  194611020CHS   NBA  ...            L  0.368899   NaN
# 4               3  194611020DTF   NBA  ...            L  0.640065   NaN
# ...           ...           ...   ...  ...          ...       ...   ...
# 126309      63155  201506110CLE   NBA  ...            L  0.546572   NaN
# 126310      63156  201506140GSW   NBA  ...            W  0.765565   NaN
# 126311      63156  201506140GSW   NBA  ...            L  0.234435   NaN
# 126312      63157  201506170CLE   NBA  ...            L  0.481450   NaN
# 126313      63157  201506170CLE   NBA  ...            W  0.518550   NaN
#
# [126314 rows x 23 columns]

# %%
# !wget - 0 nbaaellelo.csv https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv
# Out:
# --2021-08-03 09:29:40--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# --2021-08-03 09:29:40--  http://0/
# Resolving 0 (0)... 0.0.0.0
# Connecting to 0 (0)|0.0.0.0|:80... failed: Connection refused.
# --2021-08-03 09:29:40--  http://nbaaellelo.csv/
# Resolving nbaaellelo.csv (nbaaellelo.csv)... failed: Name or service not known.
# wget: unable to resolve host address ‘nbaaellelo.csv’
# --2021-08-03 09:29:40--  https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18173265 (17M) [text/plain]
# Saving to: ‘nbaallelo.csv.3’
#
# nbaallelo.csv.3     100%[===================>]  17.33M  73.9MB/s    in 0.2s
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -P '/content/drive/'My Drive/PROJECT'https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv
data = pd.read_csv('/content/drive/My Drive/PROJECT/nbaallelo.csv.3')
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-97fcf75d4a99> in <module>()
#       1 get_ipython().system("wget -P '/content/drive/'My Drive/PROJECT'https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv")
# ----> 2 data = pd.read_csv('/content/drive/My Drive/PROJECT/nbaallelo.csv.3')
#
# NameError: name 'pd' is not defined
